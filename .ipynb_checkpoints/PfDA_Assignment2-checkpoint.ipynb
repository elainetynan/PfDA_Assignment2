# %% [markdown]
# # Programming for Data Analysis Assignment 2

# %% [markdown]
# # Investigation of the Wisconsin Breast Cancer dataset

# %% [markdown]
# <a id="top"></a>
# ## Table of Contents
#  - [Introduction](#introduction)
#      - [Information about the dataset](#introdata)
#      - [Python Imports](#imports)
#      - [Import Data](#importdata)
#      - [Data information](#datainfo)
#      - [Check for missing Values](#checkmissing)
#      - [Remove Unnecessary Columns](#removecols)
#      - [Check for zeros in data](#checkzeros)
#  - [Literature Review on Classifiers](#litreview)
#      - [Summary Statistics](#summarystats)
#      - [Sample Classification](#classification)
#      - [Breakout Mean, SE and Work Columns](#breakout)
#      - [Correlation](#correlation)
#          - [Heatmap for Correlation](#heatmap)
#          - [Correlation of the Values with the Diagnosis](#correlvaluesdiagnosis)
#              - [Correlation of Mean Values with Diagnosis](#correlmeandiagnosis)
#              - [Correlation of Standard Error Values with Diagnosis](#correlsediagnosis)
#              - [Correlation of Worst Values with Diagnosis](#correlworstdiagnosis)
#      - [Compare Mean Characteristics of Cell Nuclei for the Two Diagnosis](#cellnucleidiagnosis)
#      - [Train](#train)
#      - [Nearest neighbour](#nearneighbour)
#  - [Boxplots](#boxplots)
#  - [Bibliography](#bibliography)

# %% [markdown]
# <a id="introduction"></a>
#
# ## Introduction
#
# "Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image." (UCI, 1995)

# %% [markdown]
# <a id=""></a>
#
# ## Information about the dataset
#
# The dataset was obtained from imaging from biopsies in 1992.
#
# It contains 32 columns, including an ID and a classification of the tumour as either Benign (B) or Malignant (M). The remaining 30 columns contain information about the cell nuclei. These columns characterise each biopsy with the measurements: mean, standard error and worst of the following 10 characteristics of the cell nuclei:
#  - radius
#  - texture
#  - Perimeter
#  - Area
#  - Smoothness
#  - Compactness
#  - Concavity
#  - Concave Points
#  - Symmetry
#  - Fractal Dimension
#
# There are 569 rows of data, each one correlating to an individual sample. [See Data](#importdata).
#
# There is no missing data, and 13 samples have a 0 value for all columns related to Concavity (Concavity & Concave Points). See [Missing Values](#checkmissing) and [Zero Values](#checkzeros).
#
# In the dataset there are 357 benign samples and 212 malignant samples. [See Classification](#classification).
#
# This could lead to misinformation as there is an imbalance in the number of samples for each class.
#
# Attribute Information [See Data Information](#datainfo):
#
# |  | Attribute | Domain | Data Type |
# |---|---|---|---|
# | 1. | ID number | 8670 - 911320502 | Integer |
# | 2. | Class | (B = benign, M = malignant) | Text |
# | 3-32. | Characteristics of the cell nuclei | 0 - 4254 | Real |

# %% [markdown]
# <a id="imports"></a>
#
# ### Python Imports
#
# [Back To Top](#top)

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import sklearn.neighbors as nei
import sklearn.model_selection as mod

# %% [markdown]
# <a id='importdata'></a>
#
# ### Import Data
#
# [Back To Top](#top)

# %%
# using data from Kaggle as it had the column headers already included.

#df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data")
#df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wpbc.data")
df = pd.read_csv("DataInfo/data.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# <a id='datainfo'></a>
#
# ### Data information
#
# [Back To Top](#top)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
 df.agg(['min', 'max'])
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# min       8670         B        6.981          9.71           43.79
# max  911320502         M       28.110         39.28          188.50
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# min      143.5          0.05263           0.01938          0.0000
# max     2501.0          0.16340           0.34540          0.4268
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# min               0.0000  ...          12.02            50.41       185.2
# max               0.2012  ...          49.54           251.20      4254.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# min           0.07117            0.02729            0.000
# max           0.22260            1.05800            1.252
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  \
# min                 0.000          0.1565                  0.05504
# ...

# %% [markdown]
# <a id="checkmissing"></a>
#
# ### Check for missing Values
#
# [Back To Top](#top)

# %%
num_missing = df.isnull().sum()
num_missing
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# <a id="removecols"></a>
#
# ### Remove Unnecessary Columns
#
# [Back To Top](#top)

# %%
# The last (Unnamed) colomn needs to br removed as it is generated from the end of line data
# in the.csv file. It is not part of the dataset.

df.drop(['Unnamed: 32'],axis=1,inplace=True)
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df2 = df.drop(['id'], axis=1)
df2
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# <a id='checkzeros'></a>
#
# ### Check for Zeros
#
# [Back To Top](#top)

# %%
for column in df:
    print(column + ": " + str((df[column] == 0).sum()) )
# Out:
# id: 0
# diagnosis: 0
# radius_mean: 0
# texture_mean: 0
# perimeter_mean: 0
# area_mean: 0
# smoothness_mean: 0
# compactness_mean: 0
# concavity_mean: 13
# concave points_mean: 13
# symmetry_mean: 0
# fractal_dimension_mean: 0
# radius_se: 0
# texture_se: 0
# perimeter_se: 0
# area_se: 0
# smoothness_se: 0
# compactness_se: 0
# concavity_se: 13
# concave points_se: 13
# symmetry_se: 0
# fractal_dimension_se: 0
# radius_worst: 0
# texture_worst: 0
# perimeter_worst: 0
# area_worst: 0
# smoothness_worst: 0
# compactness_worst: 0
# concavity_worst: 13
# concave points_worst: 13
# symmetry_worst: 0
# fractal_dimension_worst: 0

# %% [markdown]
# #### Note:
# All columns in relation to conclavity (Conclavity & Conclave Points) has 13 zeros in the 569 rows.
#
# No other columns have zeros.

# %% [markdown]
# <a id="litreview"></a>
#
# ## Literature Review on Classifiers
#
# [Back To Top](#top)

# %% [markdown]
# <a id="summarystats"></a>
#
# ### Summary Statistics
#
# [Back To Top](#top)
#
# In most instances of data analytics, a good starting point in the analysis is to check for missing and null values. This is part of the data cleansing stage of data analytics. Very often the next step is to get a description of the data. This often means getting a list of columns and their data types as well as the statistical summary of the actual values. This is what Sumbria (2021) has done. The following 8 statistics for the values in each column were generated:
# 1. Count
# 2. Mean
# 3. Standard Deviation
# 4. The minimum value
# 5. The first quartile
# 6. The second quartile
# 7. The third quartile
# 8. The maximum value
#
# These high-level figures give  an idea of the spread of the data for each cell nuclei characteristic.

# %%
df2.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# <a id='classification'></a>
#
# ### Sample Classification
#
# [Back To Top](#top)
#
# Most of the literature looked at the classification of the diagnosis. This was done in various ways from summary statistics, to value counts and histograms. I chose to get the values using the function *value_counts* similar to Karagiannis (2022) and then calculated the percentage of each (Benign and malignant). I then drew a bar chart of the 2 as a visual is always a good way to show data. Sumbria (2021) drew a column chart of the same data which is similar.
#
# As can be seen from the data below there are almost twice as many benign diagrnosis than malignant one.

# %%
b, m = df['diagnosis'].value_counts()
b_percent = round(float(b) / float(b + m) * 100, 2)
m_percent = round(float(m) / float(b + m) * 100, 2)
print("Benign: " + str(b) + "  (" + str(b_percent) + "%)")
print("Malignant: " + str(m) + "  (" + str(m_percent) + "%)")
# Out:
# Benign: 357  (62.74%)
# Malignant: 212  (37.26%)

# %%
# For 'kind' set to 'bar' for column chart and 'barh' for bar chart.

ax = df['diagnosis'].value_counts().sort_values().plot(kind = 'barh')
plt.title("Number of Malignant and Benign Tumours")
classes = ["Malignant", "Benign"]
ax.set_yticklabels(classes)
# Out:
# [Text(0, 0, 'Malignant'), Text(0, 1, 'Benign')]

# %% [markdown]
# <a id='breakout'></a>
#
# ### Breakout Mean, SE and Work Columns
#
# [Back To Top](#top)
#
# In the case of the Wisconsin Breast Cancer dataset a good next step is to divide the data out into the columns related to the mean of each cell nuclei characteristic, the standard error of same and finally the worst of the characteristics. Ahmad (n.d.) and Sumbria (2021) both did this as a next step.

# %%
# Break data into 3 separate dataframes. One for each of:
# 1. The Mean
# 2. The standard Error
# 3. The Worst

df_mean = df2[df2.columns[:11]]
df_se = df2.drop(df2.columns[1:11], axis=1)
df_se = df_se.drop(df_se.columns[11:], axis=1)
df_worst = df2.drop(df2.columns[1:21], axis=1)

# %% [markdown]
# <a id='correlation'></a>
#
# ### Correlation
#
# [Back To Top](#top)
#
# In many of the literature an exploratory data analysis looked at the correlation of the data. Ahmad (2020), Ahmad (n.d.), Sumbria (2021) and Yael (2017) all did correlation analysis on the data. The correlation was carried out in various ways, one of which was using a heatmap. This is replicated below in the [Heatmap for Correlation](#heatmap) section. the heatmaps are done by the ten mean columns, the ten standard error columns and the ten worst value columns, as it becomes very busy when you do all columns together and looses meaning. Another Correlation was the [Correlation of the Values with the Diagnosis](#correlsediagnosis), which can also be seen below.

# %% [markdown]
# <a id='heatmap'></a>
#
# #### Heatmap for Correlation
#
# [Back To Top](#top)
#
# The heatmap shows the correlation between the various characteristics of the cell nuclei. There is the expected diagonal of perfect correlation of each column with itself. There are also some strong correlations between obvious characteristics. Some obvious examples are Area, Perimeter and Radius; Concavity and Concave points. The concave Points are also quite strongly correlated with the Area, Perimeter, radius and Compactness. The texture has little to no correlation with any of the other characteristics. The Symmetry and Fractal Dimension also show weak correlation with all other characteristics.

# %%
f, ax = plt.subplots(figsize=(12, 7))
corr = df_mean.corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f', linewidths=.05)
t = f.suptitle('Mean Correlation Heatmap', fontsize=14)

# %% [markdown]
# <a id="correlvaluesdiagnosis"></a>
# #### Correlation of the Values with the Diagnosis
#
# [Back to Top](#top)
#
# Sumbria (2021) took a different angle on correlation and carried out a "*Correlation of Mean Features with Diagnosis*", as well as a [Correlation of Standard Error Values with Diagnosis](#correlsediagnosis), and [Correlation of Worst Values with Diagnosis](#correlworstdiagnosis).
#
# These graphs show a correlation between all Worst values, most Mean Values and more than half of the Standard Error Values, with the Diagnosis.

# %% [markdown]
# <a id="correlmeandiagnosis"></a>
# ##### Correlation of Mean Values with Diagnosis
#
# [Back to Top](#top)
#
# As can be seen from the below code there is average to strong correlation for most mean characteristics with the Diagnosis. The exception is Fractal Dimension Mean column which shows almost no correlation to the diagnosis.

# %%
df_mean_num = df_mean
df_mean_num['diagnosis_num'] = np.where(df_mean_num['diagnosis'] == 'B', 0, 1)
# Out:
# C:\Users\elaine.tynan\AppData\Local\Temp\ipykernel_38796\449719621.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(20, 8))
df_mean_num.drop(['diagnosis_num'], axis=1).corrwith(df_mean_num.diagnosis_num).plot(kind='bar', grid=True, title="Correlation of Mean Features with Diagnosis", color="darkmagenta")
plt.show()

# %% [markdown]
# <a id="correlsediagnosis"></a>
# ##### Correlation of Standard Error Values with Diagnosis
#
# [Back to Top](#top)
#
# In the case of the standard error characteristics being correlated with the Diagnosis, 6 of the characteristics have average to strong correlation with the Diagnosis and 4 do not as follows:
#
# Average to Strong correlation:
#  - Radius SE
#  - Perimeter SE
#  - Area SE
#  - Compactness SE
#  - Concavity SE
#  - Concave points SE
#
# Little to No Correlation:
#  - Texture SE
#  - Smoothness SE
#  - Symmetry SE
#  - Fractal Dimension SE

# %%
df_se_num = df_se
df_se_num['diagnosis_num'] = np.where(df_se_num['diagnosis'] == 'B', 0, 1)

# %%
plt.figure(figsize=(20, 8))
df_se_num.drop(['diagnosis_num'], axis=1).corrwith(df_se_num.diagnosis_num).plot(kind='bar', grid=True, title="Correlation of Mean Features with Diagnosis", color="rebeccapurple")
plt.show()

# %% [markdown]
# <a id="correlworstdiagnosis"></a>
# ##### Correlation of Worst Values with Diagnosis
#
# [Back to Top](#top)
#
# In this case all Worst characteristics show an average to strong correlation  with the Diagnosis.

# %%
df_worst_num = df_worst
df_worst_num['diagnosis_num'] = np.where(df_worst_num['diagnosis'] == 'B', 0, 1)

# %%
plt.figure(figsize=(20, 8))
df_worst_num.drop(['diagnosis_num'], axis=1).corrwith(df_worst_num.diagnosis_num).plot(kind='bar', grid=True, title="Correlation of Mean Features with Diagnosis", color="mediumpurple")
plt.show()

# %% [markdown]
# <a id="cellnucleidiagnosis"></a>
# ### Compare Mean Characteristics of Cell Nuclei for the Two Diagnosis
#
# [Back To Top](#top)
#
# Sumbria (2022) did a comparison of the mean characteristics grouped by diagnosis to see how the samples for each classification were different or similar. In all cases the samples for each diagnosis varied significantly.
#
# I have created similar graphs of the 10 mean characteristics below to reveal the same result.

# %%
# Sumbria
dfM = df_mean_num[df_mean_num['diagnosis_num'] == 1]
dfB = df_mean_num[df_mean_num['diagnosis_num'] == 0]

plt.rcParams.update({'font.size': 8})
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(8, 10))
axes = axes.ravel()

for i, ax in enumerate(axes):
    idx = i+1 # skip the diagnosis column which is first
    ax.figure
    col = df_mean[df_mean.columns[idx]]
    
    min = col.min()
    max = col.max()
    binwidth = (max - min) / 50
    stop = max + binwidth
    
    curbins = np.arange(min, stop, binwidth)
    ax.hist([dfM[df_mean.columns[idx]], dfB[df_mean.columns[idx]]], bins=curbins, alpha=0.5, stacked=True, label=['M', 'B'], color=['turquoise', 'goldenrod'])
    ax.legend(loc='upper right')
    ax.set_title(df_mean.columns[idx])
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id='train'></a>
#
# ### Train
#
# [Back To Top](#top)

# %%
sns.pairplot(df_mean,hue="diagnosis")

# %% [markdown]
# <a id='nearneighbour'></a>
#
# ### Nearest neighbour
#
# [Back To Top](#top)
#
# xxx.

# %%
# Slpit the dataframe into a dataframe for inputs and a dataframe for outputs.

inputs = df[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']]
outputs = df['diagnosis']

# %%
# Set up the KNN object and get the fit from the datasets

knn = nei.KNeighborsClassifier(n_neighbors=5)
knn.fit(inputs, outputs)
# Out:
# KNeighborsClassifier()

# %%
# Getting the first row of inputs so i can run the predict with it and see if I get
# the correct prediction.
inputs.loc[0]
# Out:
# radius_mean                 17.99000
# texture_mean                10.38000
# perimeter_mean             122.80000
# area_mean                 1001.00000
# smoothness_mean              0.11840
# compactness_mean             0.27760
# concavity_mean               0.30010
# concave points_mean          0.14710
# symmetry_mean                0.24190
# fractal_dimension_mean       0.07871
# Name: 0, dtype: float64

# %%
# This is the correct prediction.

outputs.loc[0]
# Out:
# 'M'

# %%
# This is what the KNN predicts.

knn.predict([[19.99,10.38,122.8,1001,0.1184,0.2776,0.3001,0.1471,0.2419,0.07871]])
# Out:
# C:\Users\elaine.tynan\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning:
#
# X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
# array(['M'], dtype=object)

# %%
# You can do multiple predictions a the same time (both of these are the same).
knn.predict([[19.99,10.38,122.8,1001,0.1184,0.2776,0.3001,0.1471,0.2419,0.07871],
             [19.99,10.38,122.8,1001,0.1184,0.2776,0.3001,0.1471,0.2419,0.07871]])
# Out:
# C:\Users\elaine.tynan\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning:
#
# X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
# array(['M', 'M'], dtype=object)

# %%
# Check the accuracy

predicted_diagnosis = knn.predict(inputs)

i = 0
count = 0
for x in predicted_diagnosis:
    if x != outputs[i]:
        #print(f"Diagnosis at index {i} is predicted to be {x} but is {outputs[i]}")
        count += 1
    i += 1
    
print(f"There are {count} incorrect diagnosis")
print(f"that is {round(count/len(outputs)*100)}% incorrect")
# Out:
# There are 52 incorrect diagnosis
# that is 9% incorrect

# %%
# A quicker way to get the number of correct predictions.

(knn.predict(inputs) == outputs).sum()
# Out:
# 517

# %%
inputs = df[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']]

# %%
# Splitting the dats int 2/3 of the rows for training and 1/3 for testing.
# No point testing teh model on data it has already seen.

inputs_train, inputs_test, outputs_train, outputs_test = mod.train_test_split(inputs, outputs, test_size = 0.33)

# Run  the KNN fit on 2/3 of the data for training and then get predisions on the remaining 1/3

knn = nei.KNeighborsClassifier(n_neighbors=5)
knn.fit(inputs_train, outputs_train)
def get_average_correct():
    sum = 0
    count = 0
    for i in range(1000):
        correct = (knn.predict(inputs_test)==outputs_test).sum()
        sum+= correct
        count += 1
    return sum/count

ans = get_average_correct()
print(f"Correctly predicted {ans} out of {len(outputs_test)}")
print(f"that is {round(correct/len(outputs_test)*100)}%")
# Out:
# Correctly predicted 168.0 out of 188
# that is 88%

# %%
# Try the predictions without the fractal dimension as that did not perform well in the correlation tests
# This did not improve it.

# drop the column and do the split again
inputs2 = inputs.drop(columns=['fractal_dimension_mean'])
inputs_train, inputs_test, outputs_train, outputs_test = mod.train_test_split(inputs2, outputs, test_size = 0.33)

# Do the taining again
knn = nei.KNeighborsClassifier(n_neighbors=5)
knn.fit(inputs_train, outputs_train)
def get_average_correct2():
    sum = 0
    count = 0
    for i in range(1000):
        correct = (knn.predict(inputs_test)==outputs_test).sum()
        sum+= correct
        count += 1
    return sum/count

ans = get_average_correct2()
print(f"Correctly predicted {ans} out of {len(outputs_test)}")
print(f"that is {round(correct/len(outputs_test)*100)}%")
# Out:
# Correctly predicted 169.0 out of 188
# that is 88%

# %% [markdown]
# <a id='boxplots'></a>
#
# ### Boxplots of Means of Smoothness, Compactness, Concavity, Concave points, Symmetry and Fractal Dimension
#
# [Back To Top](#top)

# %%
names = df2.columns[5:11]
# convert DataFrame to list
values=[] 
for column in df2.iloc[:,5:11].columns:
    li = df2[column].tolist()
    values.append(li)
colors = ['gold', 'mediumturquoise', 'darkorange', 'lightgreen','cyan', 'royalblue']

fig = go.Figure()
for xd, yd, cls in zip(names, values, colors):
        fig.add_trace(go.Box(
            y=yd,
            name=xd,
            boxpoints='outliers',
            jitter=0.5,
            whiskerwidth=0.2,
            fillcolor=cls,
            marker_size=3,
            line_width=2)
        )
fig.show()
# Out:
# <div>                            <div id="f7fd6003-b7b3-4223-8aa4-39abfebf64d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7fd6003-b7b3-4223-8aa4-39abfebf64d6")) {                    Plotly.newPlot(                        "f7fd6003-b7b3-4223-8aa4-39abfebf64d6",                        [{"boxpoints":"outliers","fillcolor":"gold","jitter":0.5,"line":{"width":2},"marker":{"size":3},"name":"smoothness_mean","whiskerwidth":0.2,"y":[0.1184,0.08474,0.1096,0.1425,0.1003,0.1278,0.09463,0.1189,0.1273,0.1186,0.08206,0.0971,0.0974,0.08401,0.1131,0.1139,0.09867,0.117,0.09831,0.09779,0.1075,0.1024,0.1073,0.09428,0.1121,0.1186,0.1054,0.0944,0.1082,0.09847,0.1064,0.1109,0.1197,0.09401,0.104,0.0961,0.09823,0.08983,0.09387,0.1016,0.08162,0.1227,0.09081,0.1041,0.
# ...

# %% [markdown]
# Traing

# %% [markdown]
# <a id="bibliography"></a>
# # Bibliography
#
# [Back To Top](#top)
#
# Abdulkareem, S.A., Abdulkareem, Z.O., (2021) “An Evaluation of the Wisconsin Breast Cancer Dataset using Ensemble Classifiers and RFE Feature Selection Technique”, International Journal of Sciences: Basic and Applied Research (IJSBAR), 55(2), pp. 67–80. Available at: https://gssrr.org/index.php/JournalOfBasicAndApplied/article/view/12300 (Accessed: 29 December 2022).
#
# Ahmed, T., Imtiaz, N., Karmakar, A., (2020) Analysis of Wisconsin Breast Cancer original dataset using data mining and machine learning algorithms for breast cancer prediction. Available at: https://www.journalbinet.com/uploads/2/1/0/0/21005390/67.02.09.2020_analysis_of_wisconsin_breast_cancer_original_dataset_using_data_mining_and_machine_learning_algorithms_for_breast_cancer_prediction.pdf (Accessed 29 December 2022)
#
# Ahmad, U.K., (n.d.) Breast Cancer Wisconsin dataset Analysis. Available at: https://deepnote.com/@umaima-khurshid-ahmad-a1fd/Wisconsin-Breast-Cancer-Analysis-7f141f92-beb3-42ac-a223-de5569144e9b (Accessed: 29 December)
#
# Barford, B., (n.d.) Machine Learning for Cancer Diagnosis and Prognosis. Available at: https://pages.cs.wisc.edu/~olvi/uwmp/cancer.html (Accessed: 29 December 2022)
#
# Karagiannis, G., (2022) Breast cancer detection using KNN and SVM. Available at: https://www.kaggle.com/code/georgioskaragiannis/breast-cancer-detection-using-knn-and-svm (Accessed: 29 December 2022)
#
# Kaggle (2016) Breast Cancer Wisconsin (Diagnostic) Data Set. Available at: https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data (Accessed: 23 December 2022)
#
# Mohammad, W.T., Teete, R., Al-Aaraj, H., Rubbai, Y.S., Arabyat, M.M., (2022) "Diagnosis of Breast Cancer Pathology on the Wisconsin Dataset with the Help of Data Mining Classification and Clustering Techniques", Applied Bionics and Biomechanics, vol. 2022, Article ID 6187275, 9 pages. Available at: https://doi.org/10.1155/2022/6187275 (Accessed: 27 December 2022)
#
# Sumbria, S., (2021) Breast Cancer Wisconsin (Diagnostic) - Exploratory Data Analysis. Available at: https://medium.com/analytics-vidhya/breast-cancer-diagnostic-dataset-eda-fa0de80f15bd#:~:text=This%20is%20clean%20Breast%20Cancer%20Wisconsin%20(Diagnostic)%20Data%20Set&text=Features%20are%20computed%20from%20a,(MSM%2DT)%20%5BK.%20P. (Accessed 27 December 2022)
#
# UCI, (1995) Breast Cancer Wisconsin (Diagnostic) Data Set. Available at: https://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+(diagnostic) (Accessed: 16 December 2022)
#
# UCI, (1992) Breast Cancer Wisconsin (Original) Data Set. Available at: https://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+%28original%29 (Accessed: 16 December 2022)
#
# Yael, K. (2017) Wisconsin Breast Cancer (Diagnostic) DataSet Analysis. Available at: https://rstudio-pubs-static.s3.amazonaws.com/344010_1f4d6691092d4544bfbddb092e7223d2.html (Accessed: 28 December 2022)
#
# Zhang, Y., (2019) Deep Learning in Wisconsin Breast Cancer Diagnosis. Available at: https://towardsdatascience.com/deep-learning-in-winonsin-breast-cancer-diagnosis-6bab13838abd (Accessed 28 December 2022)
